# %%
import requests
import json

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

# %%
def connect_to_endpoint(url, params):
    response = requests.request("GET", url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def main(url, params):
    json_response = connect_to_endpoint(url, params)
    return json_response
    # return json.dumps(json_response, indent=4, sort_keys=True)

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAACneVAEAAAAAhW%2F817SyKyUJFPkADBo3okR3c8Q%3DppOMzyrqdESlcqsyzE2ob4ikmDyxLJhGyD0ExEdK2Y9UJAKF72"

search_url = "https://api.twitter.com/2/tweets/search/recent"
count_url = "https://api.twitter.com/2/tweets/counts/recent"

adidas_search_params = {'query': 'adidas lang:en context:47.10026773952 is:verified', 'tweet.fields': 'author_id,public_metrics,created_at', 'max_results': 100}
adidas_count_params = {'query': 'adidas lang:en context:47.10026773952 is:verified', 'granularity': 'day'}

walmart_count_params = {'query': 'walmart lang:en is:verified', 'granularity': 'day'}
walmart_search_params = {'query': 'walmart lang:en is:verified', 'tweet.fields': 'author_id,public_metrics,created_at', 'max_results': 100}

# %%
main(count_url, walmart_count_params)
# Out:
# 200
# {'data': [{'end': '2021-10-26T00:00:00.000Z',
#    'start': '2021-10-25T20:22:48.000Z',
#    'tweet_count': 66},
#   {'end': '2021-10-27T00:00:00.000Z',
#    'start': '2021-10-26T00:00:00.000Z',
#    'tweet_count': 311},
#   {'end': '2021-10-28T00:00:00.000Z',
#    'start': '2021-10-27T00:00:00.000Z',
#    'tweet_count': 418},
#   {'end': '2021-10-29T00:00:00.000Z',
#    'start': '2021-10-28T00:00:00.000Z',
#    'tweet_count': 322},
#   {'end': '2021-10-30T00:00:00.000Z',
#    'start': '2021-10-29T00:00:00.000Z',
#    'tweet_count': 251},
#   {'end': '2021-10-31T00:00:00.000Z',
#    'start': '2021-10-30T00:00:00.000Z',
#    'tweet_count': 190},
#   {'end': '2021-11-01T00:00:00.000Z',
#    'start': '2021-10-31T00:00:00.000Z',
#    'tweet_count': 108},
#   {'end': '2021-11-01T20:22:48.000Z',
#    'start': '2021-11-01T00:00:00.000Z',
#    'tweet_count': 7335}],
#  'meta': {'total_tweet_count': 9001}}

# %%
import pandas as pd

# %%
df = pd.json_normalize(main(search_url, walmart_search_params)['data'])
# Out:
# 200

# %%
df
# Out:
#                      id                created_at  \
# 0   1455270955715072001  2021-11-01T20:30:08.000Z
# 1   1455270126148849665  2021-11-01T20:26:50.000Z
# 2   1455268866137939969  2021-11-01T20:21:49.000Z
# 3   1455268797494042627  2021-11-01T20:21:33.000Z
# 4   1455268406031261697  2021-11-01T20:20:00.000Z
# ..                  ...                       ...
# 95  1455237154347659264  2021-11-01T18:15:49.000Z
# 96  1455236896813195274  2021-11-01T18:14:47.000Z
# 97  1455236762977062914  2021-11-01T18:14:15.000Z
# 98  1455236476699123716  2021-11-01T18:13:07.000Z
# 99  1455236261296459783  2021-11-01T18:12:16.000Z
#
#                                                  text   author_id  \
# 0   A lot is changing at America's largest retail ...    32122637
# 1   @vloo1010 @Walmart Will try again when they op...   331854460
# 2   When you have 3 skill players making 42 mill b...  1377102601
# 3   RT @GRATATATheGREAT: Like my pic if you’ll suc...  2412290671
# ...
